# %%
# !pip install pandas_profiling

# %%
import pandas as pd
import pandas_profiling

# %%
df = pd.read_csv('C:/Users/Shailesh/test.csv')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ad                      object
# date            datetime64[ns]
# price                    int64
# county                  object
# make                    object
# model                   object
# year                     int64
# colour                  object
# mileage                  int64
# mileageType             object
# engine_cc                int64
# body_type               object
# fuel_type               object
# transmission            object
# doors                    int64
# seller_type             object
# dtype: object

# %%
report = pandas_profiling.ProfileReport(df)

# %%
report.to_file("E:/report.html")

# %%
report
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
